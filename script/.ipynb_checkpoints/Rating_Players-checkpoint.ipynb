# %%
import pandas as pd

# On récupère les données de stats
data_opta_analyst = pd.read_csv("../data/silver_analyst.csv")
data_ids = pd.read_csv("../data/entity_resolution.csv")

# %%
import hashlib

def create_player_id(analyst_name):
    return hashlib.sha256(str(analyst_name).encode("utf-8")).hexdigest()[:16]

data_ids["opta_id"] = data_ids["analyst_name"].apply(create_player_id)

# %%
data_ids
# Out:
#               analyst_name  best_tm_id best_method  fuzzy_score  \
# 0             Aaron Greene    122407.0        reep          NaN
# 1          Aarón Escandell    284430.0        reep          NaN
# 2            Aarón Herrera    401362.0        reep          NaN
# 3             Aarón Martín    251878.0        reep          NaN
# 4             Abakar Sylla    962555.0        reep          NaN
# ..                     ...         ...         ...          ...
# 995              Bob Armah   1147796.0       fuzzy         95.0
# 996            Bobby Clark    142701.0        reep          NaN
# 997  Bobby De Cordova-Reid    186186.0        reep          NaN
# 998         Bobby Faulkner    876779.0        reep          NaN
# 999            Bobby Kamwa    559797.0        reep          NaN
#
#             reep_id  fotmob_id  sofascore_id  fbref_id  understat_id  \
# 0    reep_pf7029e95        NaN           NaN       NaN           NaN
# 1    reep_pbc6fe046   534955.0      368922.0  67669ce7           NaN
# 2    reep_pcdb31119        NaN           NaN  d86e3070           NaN
# 3    reep_pe0bb5f2e   684981.0      797286.0  2f3e911a           NaN
# 4    reep_peeaa665d  1359613.0     1170197.0       NaN           NaN
# ..              ...        ...           ...       ...           ...
# 995             NaN        NaN           NaN       NaN           NaN
# 996  reep_pbf5117a5        NaN           NaN  e381f2ae           NaN
# 997  reep_pd1e94d61        NaN      151499.0  0f7533cd        6827.0
# 998  reep_pb705e9b0        NaN     1161941.0       NaN           NaN
# 999  reep_p69ede8b8        NaN     1020687.0  7d8090a8           NaN
#
#               opta_id
# 0    41e1a6833619b240
# 1    be5c61f30246a2b9
# 2    bf8da63c2c534563
# 3    17b08b01696a4b12
# 4    1b43e3b148b564e9
# ..                ...
# 995  a7204df66bb9e33e
# 996  5c86e6c6b4bb0905
# 997  a37ff64cd47e8cf8
# 998  09f4e529fa9ea1d3
# 999  992169b6b30d6156
#
# [1000 rows x 10 columns]

# %%
cols_ids = [
    "best_tm_id",
    "sofascore_id",
    "opta_id"
]

n_complet = data_ids[cols_ids].notna().all(axis=1).sum()

print(n_complet)

n_total = len(data_ids)
pct_complet = n_complet / n_total * 100

print(f"{n_complet} lignes sur {n_total} ({pct_complet:.1f} %)")
# Out:
# 732
# 732 lignes sur 1000 (73.2 %)
